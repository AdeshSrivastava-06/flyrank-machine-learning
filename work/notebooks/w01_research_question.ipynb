# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
I chose the Refresh / Content Opportunity Scoring lane because it focuses on helping reviewers prioritize which content pages should be reviewed first. Instead of manually checking every page, this project uses observable search and engagement signals to rank pages based on their potential need for refresh. I chose this lane because it combines exploratory data analysis, feature engineering, and machine learning to solve a practical business problem while producing explainable recommendations.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
Decision:Which content pages should be reviewed first for refresh or improvement?

Who acts on it? Content editors, SEO analysts, or marketing teams who are responsible for maintaining website content.

Action: Review the highest-ranked pages and decide whether they should be refreshed, expanded, optimized for CTR, monitored, or left unchanged.

Cost of a wrong recommendation: If an important page is missed, valuable search traffic and user engagement may decline. If a low-priority page is recommended instead, the team wastes time and effort reviewing content that is unlikely to provide meaningful improvements.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("content_refresh_anonymized.csv")

print(df.shape)
print(df["impressions_90d"].mean())
print(df["ctr"].mean())
print(df["trend_direction"].value_counts())
# Out:
# (30000, 44)
# 5200.3663
# 0.5107333333333334
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
This project provides decision-support based on observed search and engagement signals. It can identify patterns that are associated with pages that may benefit from review and produce a ranked list of candidates for further inspection. However, it does not prove that refreshing a page will cause an increase in traffic or rankings, nor does it predict Google's search algorithm. All findings are observational and should be used to support, not replace, human judgment

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
